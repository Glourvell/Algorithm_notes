# %% [markdown]
# <a href="https://colab.research.google.com/github/Glourvell/Algorithm_notes/blob/main/Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LINEAR REGRESSION:
# - A statistical method that's used for predictive analysis
# - It makes predictions of conitnous data e.g sales, age, prices

# %% [markdown]
# 2. SUPPORT VECTOR MACHINE (SVM)
# - It's a supervised learning algorithm
# - It's used for both regression and classification problems
# - It's classified into two:
# - i. Linear SVM: This is whereby the data is separated by a line and then the different data is used for classification
# - ii. Non-linear SVM:
# - It can be used for: face detection, image classification, text categorization

# %% [markdown]
# 3. NAIVE BAYES
# - Used for classification problems
# - Mainly used in text classification
# - Assumes no relationships across the given data that's why it's fast and it's called naive
# - It's the fastest and easiest to predict data
# Used for:
# - (credit scoring, medical data classification, real-time predictions, spam filtering)
